# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# Com o drive montado, é neceessário instalar as dependências dos sumarizadores pelo pip. Alguns pacotes tiveram que ser atualizados devido a problemas na instalação das versões passadas pelo arquivo requirements.txt.

# %%
# !ls "/content/drive/MyDrive/Proj_PFC/Condori_algs"
# !pip install numpy nlpnet nltk networkx scikit-learn
# Out:
# Opizer_E+Tadano.ipynb  README.md  requirements.txt  resource  src
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (1.21.6)
# Requirement already satisfied: nlpnet in /usr/local/lib/python3.7/dist-packages (1.2.4)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (3.7)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (2.6.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (1.0.2)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from nlpnet) (1.15.0)
# Requirement already satisfied: h5py>=2.8.0rc1 in /usr/local/lib/python3.7/dist-packages (from nlpnet) (3.1.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk) (7.1.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.7/dist-packages (from nltk) (2022.6.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from nltk) (4.64.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.8.0rc1->nlpnet) (1.5.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.7.3)

# %% [markdown]
# Pacotes do nltk necessários para executar os sumarizadores tadano e opizer-E VV

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# Teste de execução do sumarizador tadano no corpus buscapé VV

# %%
# %cd /content/drive/MyDrive/Proj_PFC/Condori_algs/src
# !python main.py tadano buscape
# Out:
# /content/drive/MyDrive/Proj_PFC/Condori_algs/src
# Starting process ...
# Generating summary for Samsung-Smart-TV
# Aspecto: Samsung Smart TV
# ['Propaganda enganosa', 'Custo benefício não compensa.']
# Aspecto: Durabilidade
# ['Durabilidade 0', 'A TV é maravilhosa, porém queimou com menos de dois anos de uso e o conserto na autorizada fica o preço de uma nova.']
# Aspecto: Preço
# ['O que não gostei: Valor muito alto', 'O que não gostei: Preço alto']
# Aspecto: Câmera
# ['O que não gostei: A câmera poderia ter movimentação horizontal de visão e não só apenas vertical.', 'A câmera embutida na tv com sensor de movimento e presença funciona bem e impressiona quem não conhece.']
# Aspecto: Qualidade da imagem
# ['Excelante aparelho de TV com ótima qualidade de imagem e recursos.']
# Generating summary for Galaxy-SIII
# Traceback (most recent call last):
#   File "main.py", line 43, in <module>
#     tadano = Tadano_Summarizer(item, item_path, corpus_reader)
#   File "/content/drive/MyDrive/Proj_PFC/Condori_algs/src/tadano_summarizer.py", line 37, in __init__
#     self.__read_files(opinions_path)
#   File "/content/drive/MyDrive/Proj_PFC/Condori_algs/src/tadano_summarizer.py", line 60, in __read_files
#     self.__calculate_tfidf(float(len(files)), all_words)
#   File "/content/drive/MyDrive/Proj_PFC/Condori_algs/src/tadano_summarizer.py", line 83, in __calculate_tfidf
#     self.__create_vectors(all_words.keys())
#   File "/content/drive/MyDrive/Proj_PFC/Condori_algs/src/tadano_summarizer.py", line 101, in __create_vectors
#     self.__iterate_aspects(vectors, id_sentences)
#   File "/content/drive/MyDrive/Proj_PFC/Condori_algs/src/tadano_summarizer.py", line 118, in __iterate_aspects
#     self.__kmeans(aspect, vectors_aspect, id_sentences_aspect)
#   File "/content/drive/MyDrive/Proj_PFC/Condori_algs/src/tadano_summarizer.py", line 139, in __kmeans
#     self.__search_representative_words(aspect)
#   File "/content/drive/MyDrive/Proj_PFC/Condori_algs/src/tadano_summarizer.py", line 143, in __search_representative_words
#     tagger = nlpnet.POSTagger()
#   File "/usr/local/lib/python3.7/dist-packages/nlpnet/taggers.py", line 205, in __init__
#     self._load_data()
#   File "/usr/local/lib/python3.7/dist-packages/nlpnet/taggers.py", line 424, in _load_data
#     self.reader = create_reader(md)
#   File "/usr/local/lib/python3.7/dist-packages/nlpnet/taggers.py", line 55, in create_reader
#     tr = POSReader(md, filename=gold_file)
#   File "/usr/local/lib/python3.7/dist-packages/nlpnet/pos/pos_reader.py", line 40, in __init__
#     super(POSReader, self).__init__(md, load_dictionaries=load_dictionaries)
#   File "/usr/local/lib/python3.7/dist-packages/nlpnet/reader.py", line 78, in __init__
#     self.load_or_create_dictionary()
#   File "/usr/local/lib/python3.7/dist-packages/nlpnet/reader.py", line 96, in load_or_create_dictionary
#     self.load_dictionary()
#   File "/usr/local/lib/python3.7/dist-packages/nlpnet/reader.py", line 256, in load_dictionary
#     wd = WordDictionary.init_from_wordlist(words)
#   File "/usr/local/lib/python3.7/dist-packages/nlpnet/word_dictionary.py", line 87, in init_from_wordlist
#     return cls(None, wordlist=wordlist)
#   File "/usr/local/lib/python3.7/dist-packages/nlpnet/word_dictionary.py", line 55, in __init__
#     for word in wordlist]
#   File "/usr/local/lib/python3.7/dist-packages/nlpnet/word_dictionary.py", line 55, in <listcomp>
#     for word in wordlist]
# KeyboardInterrupt

# %% [markdown]
# Teste de execução do sumarizador opizer-E no corpus buscapé VV

# %%
# %cd /content/drive/MyDrive/Proj_PFC/Condori_algs/src
# !python main.py opizere buscape

# %% [markdown]
# As atualizações dos algoritmos a serem utilizados para o Python 3 não parecem ter causado problemas, já que os resultados gerados são idênticos aos presentes no repositório original de Condori. Agora restam as adaptações em código e no corpus para que estes consigam sumarizar as opiniões sobre hoteis.

# %% [markdown]
# Com as devidas adaptações feitas, basta utilizar o comando abaixo para executar o Opizer-E sobre o corpus do tripadvisor VV

# %%
# %cd /content/drive/MyDrive/Proj_PFC/Condori_algs/src
# !python main.py opizere tripadvisor
# Out:
# /content/drive/MyDrive/Proj_PFC/Condori_algs/src
# Starting process ...
# Generating summary for Hotel1
# Generating summary for Hotel2
# Generating summary for Hotel4
# Generating summary for Hotel5
# Generating summary for Hotel3
# Process finished

# %% [markdown]
# Para o sumarizador de tadano, apenas o nome do sumarizador precisa ser alterado VV

# %%
# %cd /content/drive/MyDrive/Proj_PFC/Condori_algs/src
# !python main.py tadano tripadvisor
# Out:
# /content/drive/MyDrive/Proj_PFC/Condori_algs/src
# Starting process ...
# Generating summary for Hotel1
# Aspecto: Atendimento
# ['Muito bem atendita e recepcionada.', 'Excelentes e educados funcionários.']
# Aspecto: Acomodação
# ['Água quentinha do chuveiro.', 'Ficamos no quarto luxo, com banheira de imersão.']
# Aspecto: Instalação
# ['Hotel antigo e com aspecto decadente', 'Check in rápido, ótimas instalações.']
# Aspecto: Comida
# ['Atendimento bom e almoço saboroso', 'Café da manhã excelente.']
# Aspecto: Ruído
# ['Quarto silencioso.', 'Hospedes conversam e você nao consegue descansar.']
# Generating summary for Hotel2
# Aspecto: Atendimento
# ['Tive um problema com a TV e em poucos minutos o pessoal da manutenção resolveu.', 'Minha experiência foi péssima, fiz a reserva pelo telefone. Ao chegar, disseram que não tinha reserva feita. Em fim, consegui um quarto.']
# Aspecto: Acomodação
# ['Aproveitei p ver tbm o banheiro e ainda estou incrédula! Fui pessoalmente à recepção e com fotos, reclamei qto a sujeira.', 'Colchão esta necessitando de troca.  Fizemos uso de duas refeições e as duas além de demoradas, uma esquecida e a outra com troca do pedido.']
# Aspecto: Comida
# ['Restaurante comida muito boa, de qualidade, rápido atendimento, pessoal num atendimento de classe.', 'Colchão esta necessitando de troca.  Fizemos uso de duas refeições e as duas além de demoradas, uma esquecida e a outra com troca do pedido.']
# Aspecto: Instalação
# ['Sujo e mal conservado!', 'Academia com horário marcado e sauna fechada por conta da pandemia.']
# Aspecto: Internet
# ['Problemas com internet e barulho', 'Talvez os maiores problemas do hotel sejam as camas, os travesseiros e a internet, que nem sempre funciona bem.']
# Generating summary for Hotel4
# Aspecto: Atendimento
# ['Receptivo, limpo e agradável', 'Equipe toda excelente!  Funcionários muito atenciosos e prontos para ajudar sempre que preciso! Atendimento maravilhoso..... Amei!']
# Aspecto: Acomodação
# ['A estadia foi maravilhosa, excelência nos serviços limpeza e arrumação.', 'Receptivo, limpo e agradável']
# Aspecto: Comida
# ['Para não dizer que tudo é perfeito infelizmente há pouca ou quase nenhuma opção para comer nas proximidades ainda assim, o hotel oferece boas opções cardápio caso sair não esteja nos seus planos.', 'Ambiente ótimo tanto no quarto quanto no saguão. Restaurante excelente e de ambiente agradável.']
# Aspecto: Instalação
# ['Possui piscina e quadra de tenis.portas com isolamento acústico.', 'Melhor orientação quanto ao estacionamento... cada vez que sai e volta é muito chato as cancelas e o atendente da operadora de mau humor permanente... mal te olha... inclusive estava chovendo, sem apoio de manobrista...']
# Aspecto: Internet
# ['Hotel muito luxuoso, quarto super confortável, ótimo atendimento, café da manhã incrível, tudo acima do esperado, exceto pela internet lenta e dificuldade de usar aplicativos de transporte pelo acesso demorado ao hotel, por causa da localização não tão privilegiada.']
# Generating summary for Hotel5
# Aspecto: Atendimento
# ['Todos os serviços de excelente qualidade', 'Hotel Razoável, algumas coisas poderiam melhorar, como limpeza dos quartos, falta de informações sobre melhores restaurantes e pontos turísticos do Ceará por parte dos funcionários da recepção e ter uma garagem.']
# Aspecto: Acomodação
# ['Recepcao acolhedora, roupa de cama e banho limpas e cheirosas, piscina limpa , funcionários prestativo e atenciosos, próxima a praia super recomendo', 'O ar condicionado é muito barulhento e o frigobar poderia ser mais generoso.']
# Aspecto: Instalação
# ['A luz do corredor do meu andar não acendia e eu tinha que ligar a luz do celular para encontrar minha porta! Reclamei na recepção, mas não adiantou!', 'Televisão não funcionava, solicitado reparo durante o dia e não foi feito. Dias de péssima estadia.']
# Aspecto: Comida
# ['Localização excelente café da manhã variado e delicioso.', 'Realmente o foco hotel é os grupos de empresa de turismo, ou seja, pacotes fechados.  Mas vale ressaltar que o café da manhã é excelente, bem variado e com um atendimento excelente.']
# Generating summary for Hotel3
# Aspecto: Atendimento
# ['Um hotel acolhedor e de altíssimo gabarito,tanto estrutural quanto aos profissionais de excelência.', 'Café da manhã bom, mas o checkin mt demorado demais.']
# Aspecto: Comida
# ['PERFEIÇÃO CULINÁRIA', 'Café da manhã com apresentação ruim.']
# Aspecto: Acomodação
# ['Banheiro com bom tamanho, limpeza e conservação razoável.', 'Os quartos são muito espaçosos e com design moderno, tudo muito bonito.']
# Aspecto: Instalação
# ['Piscina muito suja e área externa mal cuidada.', 'Academia com os equipamentos necessários. Custo benefício excelente.']
# Aspecto: Internet
# ['Contras:  Internet (imperdoável), elevador demorado, crivo do chuveiro, vazão do ralo, sauna com odor ruim', 'Avaliação de viajante de negócios:    1- Quarto ok - espaço bom.  2- Ducha fria. Se você tiver que sair cedo do hotel, esquece. Ela vai esquentar só depois das 9h se você abrir o registro as 7h.  3- Room service sem opção de cardápio.  4- café da manhã sem variação.  5- Frigobar ok - abastecido.  6 - Limpeza ok - camareira diária.  7- Atendimento zero. Se você busca por um “bom dia/tarde ou cordialidade... esquece. O máximo que você vai ouvir é um “não posso fazer nada” ou “ah é assim mesmo e é o que temos a oferecer”.  8- internet boa. Baixei um relatório de 41Mb em 6 segundos.']
# Process finished
