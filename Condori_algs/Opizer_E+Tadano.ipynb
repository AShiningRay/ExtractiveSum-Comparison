# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# Com o drive montado, é neceessário instalar as dependências dos sumarizadores pelo pip. Alguns pacotes tiveram que ser atualizados devido a problemas na instalação das versões passadas pelo arquivo requirements.txt.

# %%
# !ls "/content/drive/MyDrive/Proj_PFC/Condori_algs"
# !pip install numpy nlpnet nltk networkx scikit-learn
# Out:
# Opizer_E+Tadano.ipynb  README.md  requirements.txt  resource  src
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.3/393.3 KB 12.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for nlpnet: filename=nlpnet-1.2.4-cp38-cp38-linux_x86_64.whl size=2824220 sha256=07021916ea63ac2459a34f391ff737fdf32af14377bf3380814efc4f776a9109
#   Stored in directory: /root/.cache/pip/wheels/55/38/b7/f411896eb7bfd55fa3ae08d50d364114c7039562a237ae20ce
# Successfully built nlpnet
# ...

# %% [markdown]
# Pacotes do nltk necessários para executar os sumarizadores tadano e opizer-E VV

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# Teste de execução do sumarizador tadano no corpus buscapé VV

# %%
#%cd /content/drive/MyDrive/Proj_PFC/Condori_algs/src
#!python main.py tadano buscape

# %% [markdown]
# Teste de execução do sumarizador opizer-E no corpus buscapé VV

# %%
#%cd /content/drive/MyDrive/Proj_PFC/Condori_algs/src
#!python main.py opizere buscape

# %% [markdown]
# As atualizações dos algoritmos a serem utilizados para o Python 3 não parecem ter causado problemas, já que os resultados gerados são idênticos aos presentes no repositório original de Condori. Agora restam as adaptações em código e no corpus para que estes consigam sumarizar as opiniões sobre hoteis.

# %% [markdown]
# Com as devidas adaptações feitas, basta utilizar o comando abaixo para executar o Opizer-E sobre o corpus do tripadvisor VV

# %%
# %cd /content/drive/MyDrive/Proj_PFC/Condori_algs/src
# !python main.py opizere tripadvisor
# Out:
# /content/drive/MyDrive/Proj_PFC/Condori_algs/src
# Starting process ...
# Generating summary for Hotel2
# Generating summary for Hotel4
# Generating summary for Hotel3
# Generating summary for Hotel5
# Generating summary for Hotel1
# Process finished

# %% [markdown]
# Para o sumarizador de tadano, apenas o nome do sumarizador precisa ser alterado VV

# %%
# %cd /content/drive/MyDrive/Proj_PFC/Condori_algs/src
# !python main.py tadano tripadvisor
# Out:
# /content/drive/MyDrive/Proj_PFC/Condori_algs/src
# Starting process ...
# Generating summary for Hotel2
# NUM_Aspectos: 5
# NUM_Sentencas: 10
# NUM_Aspectos: 5
# NUM_Sentencas: 10
# NUM_Aspectos: 5
# NUM_Sentencas: 10
# NUM_Aspectos: 5
# NUM_Sentencas: 10
# NUM_Aspectos: 5
# NUM_Sentencas: 10
# Generating summary for Hotel4
# NUM_Aspectos: 5
# NUM_Sentencas: 10
# NUM_Aspectos: 5
# NUM_Sentencas: 10
# NUM_Aspectos: 5
# NUM_Sentencas: 10
# NUM_Aspectos: 5
# NUM_Sentencas: 10
# NUM_Aspectos: 5
# NUM_Sentencas: 10
# Generating summary for Hotel3
# NUM_Aspectos: 5
# NUM_Sentencas: 10
# NUM_Aspectos: 5
# NUM_Sentencas: 10
# NUM_Aspectos: 5
# NUM_Sentencas: 10
# NUM_Aspectos: 5
# NUM_Sentencas: 10
# NUM_Aspectos: 5
# NUM_Sentencas: 10
# Generating summary for Hotel5
# NUM_Aspectos: 5
# NUM_Sentencas: 10
# NUM_Aspectos: 5
# NUM_Sentencas: 10
# NUM_Aspectos: 5
# NUM_Sentencas: 10
# NUM_Aspectos: 5
# NUM_Sentencas: 10
# NUM_Aspectos: 5
# NUM_Sentencas: 10
# Generating summary for Hotel1
# ...
