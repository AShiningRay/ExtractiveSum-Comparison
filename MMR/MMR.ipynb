# %% [markdown]
# Mounts the Google Drive folder to allow the code to be read, and save files.

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# Installs and imports nltk in order to download the punkt tokenizer

# %%
# !pip install nltk
import nltk
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# Executes the Maximal Marginal Relevance text summarizer.

# %%
# %cd /content/drive/MyDrive/Proj_PFC/MMR/
# !python main_mmr.py
# Out:
# /content/drive/MyDrive/Proj_PFC/MMR
# ...
